# %%
from neural_network import NeuralNetwork

net = NeuralNetwork()
net.train()
net.query()
# Out:
# Init does nothing yet, but hello anyway!
# Train does nothing yet, but hello anyway!
# Query does nothing yet, but hello anyway!
